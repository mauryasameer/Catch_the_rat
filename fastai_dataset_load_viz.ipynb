# %% [markdown]
# <a href="https://colab.research.google.com/github/mauryasameer/Catch_the_rat/blob/master/fastai_dataset_load_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9a6d22e3-c402-43ee-8fe4-e670c43e49b8" name="files[]" multiple disabled />
#      <output id="result-9a6d22e3-c402-43ee-8fe4-e670c43e49b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mauryasameer47","key":"e9a169c1216ef9cf2bd4ca14522808af"}'}

# %%
# !mv kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
from fastai import *
from fastai.vision import *
# import kaggle

# %%
# !kaggle datasets list
# Out:
# ref                                                         title                                                size  lastUpdated          downloadCount
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# new-york-state/nys-environmental-remediation-sites          NYS Environmental Remediation Sites                   3MB  2019-07-23 08:22:57            607
# new-york-city/new-york-city-current-job-postings            New York City Current Job Postings                    3MB  2019-07-21 22:04:51           3928
# AnalyzeBoston/crimes-in-boston                              Crimes in Boston                                     10MB  2018-09-04 17:56:03           3590
# jealousleopard/goodreadsbooks                               Goodreads-books                                     632KB  2019-06-14 16:35:05           4444
# ...

# %%
mnist = untar_data(URLs.MNIST_TINY)

# %%
tfms = get_transforms()

# %%
# data = ImageDataBunch.from_folder(path=path,valid_pct=0.2,ds_tfms=get_transforms(flip_vert=True,max_warp=0),size=224,bs=64)

# %%
# data = (ImageList.from_folder(mnist)
#         .split_by_folder()          
#         .label_from_folder()
#         .transform(tfms, size=32)
#         .databunch()
#         .normalize(imagenet_stats))

# %%
data = ImageDataBunch.from_folder(path = mnist, valid_pct=0.2, ds_tfms = tfms, size = 224, bs = 64)

# %%
data.show_batch()

# %%
data1 = (ImageList.from_folder(mnist)
        .split_by_folder()          
        .label_from_folder()
        .transform(tfms, size=64)
        .databunch()
        .normalize(imagenet_stats))

# %%
data1.show_batch()

# %%
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (1143 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# 3,3,3,3,3
# Path: /root/.fastai/data/mnist_tiny;
#
# Valid: LabelList (285 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# 3,3,7,test,7
# Path: /root/.fastai/data/mnist_tiny;
#
# Test: None

# %%
data.show_batch()

# %%
cifar = untar_data(URLs.CIFAR_100)

# %%
cifar_data = ImageDataBunch.from_folder(cifar, valid_pct=0.2, ds_tfms = get_transforms(), size = 480, bs = 64)

# %%
cifar_data.show_batch()
